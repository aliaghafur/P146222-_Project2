# %% [markdown]
# <a href="https://colab.research.google.com/github/aliaghafur/P146222-_Project2/blob/main/_P146222__Project_2_Hotel_Analysis_SEM1_20242025_20250126.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introduction**

# %% [markdown]
# This dataset contains information about hotel bookings for two hotel groups from July, 2015 until August, 2017.  This dataset contains 3024 observations (rows) and 32 variables. This dataset has been taken from github, known as Hotel Data Analysis and has been written by Shridhar Kamathe. The datasets are from three csv files (Data_2015, Data_2016, Data_2017).
#
# - Github Link: https://github.com/shridharkamathe/Hotel-Data-Analysis/tree/main/Hotel%20Data%20Analysis
#
# By analysing this dataset, we can provide valuable insights to assist
# and guide related businessess to improve the business, increase their profitability and optimize their business operations. Average daily rate (ADR) is one of the most important for hotel analysis , which can help the hotel increase their revenue. The higher the ADR means that more revenue per occupied room significantly boosts the hotel's overall profitability.
#
# In this dataset contains two types of hotel: City Hotels and Resort Hotels. In my opinion,  these two types differ significantly in terms of their location, primary focus of business and availables amenities. For example, City Hotels typically located in urban centers, close to shopping areas and easily accessible by public transport. In contrast, Resort Hotels are often situated in scenic locations, such as near to beaches, mountains, or lakes.

# %% [markdown]
# ### Variables Discriptions:
# The followings are variables in dataset:
#
# 1. **hotel** : type of hotel
# 2. **is_canceled** : value indicating if the booking is canceled or not (0==no, 1==yes)
# 3. **lead_time** : no. of days before actual arrival of the guests
# 4. **arrival_date_year** : year of arrrival date
# 5. **arrival_date_month** : month of arrival date
# 6. **arrival_date_week_number** : week no. of year for arrival date
# 7. **arrival_date_day_of_month** : day of arrival date
# 8. **stays_in_weekend_nights** : no. of nights (Saturday and Sunday) guest booked
# 9. **stays_in_week_nights** : no. of nights (Mondat to Fiday) guest booked
# 10. **adults**: no. of adults
# 11. **children** : no of children
# 12. **babies** : no of babies
# 13. **meal**: Type of meal booked.  (Undefined/SC - no meal package);
# (BB - Bed & Breakfast);
# HB-Half board: (breakfast and one other meal- usually dinner);
# (FB - Full board (breakfast, lunch and dinner)
# 14. **country** : country of origin (ISO 3155 - 3:2013)
# 15. **market_segment** : Online TA, Direct, Groups, Offline TA/TO, Complementary, Corporate, Aviation.
# (TA-Travel Agents, TO-Tour Operators)
# 16. **distribution_channel** : TA/TO, Direct, Corporate, GDS.
# 17. **is_repeated_guest** : (0==no, 1==yes)
# 18. **previous_cancellations** : no. of previous bookings that were cancelled
# 19. **previous_bookings_not_canceled** : no of previous bookings that were not cancelled
# 20. **reserved_room_type**: Code of room type reserved (8 types)
# 21. **assigned_room_type** : Code for the type of room assigned to the guests (10 types)
# 22. **booking_changes** : no of changes made to the booking
# 23. **deposit_type** : No Deposit, Non Refund, Refundable
# 24. **agent** : ID of travel agency that made the booking
# 25. **company** : ID of company
# 26. **days_in_waiting_list** : no. of days the booking was in the waiting list before it was confirmed to the customer
# 27. **customer_type** : Transient, Transient-Party, Contrac, Group.
# 28. **adr** : Average daily rate
# 29. **required_car_parking_spaces** : no. of parking spaces required by the customer
# 30. **total_of_special_requests** : no. of special requests made by the customer
# 31. **reservation_status** : Canceled, Check-Out, No-Show
# 32. **reservation_starus_date** : date at which the last reservation status was updated.
#
# We will use a few of variables that related to our purpose of analysis.

# %% [markdown]
# # **Purpose of Analysis**

# %% [markdown]
# Our main focus is explore and analyse the following key areas that can help us uncover significant loopholes and gain valuable insights to drive a profitable hotel business.:
#
#
# 1.   Customer Preferred:
#     - To analyse the most popular room types book by guests.
#     - To determine the most distribution channel.
#     - To identify the most frequent type of meal booked by customers.
#     - To determine whether guest prefer to stay during weekdays or weekends.
#
# 2.   Average Daily Rate (ADR):
#     - To understand  how well the hotel is meeting customer expectations in terms of room type.
#
# 3.   Cancellation:
#     - Does the room assigned to guests, number of days before actual arrival of guests, market segments and type of deposits give an impact to the booking cancellation?

# %% [markdown]
# # **Data Cleaning**

# %%
# import the library
import pandas as pd
import numpy as np

# %%
# read the Data_2015.csv into data frames
df = pd.read_csv('/content/Data_2015.csv')

# %%
# dataset only for Data_2015
df
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 0    Resort Hotel            1          4               2015
# 1      City Hotel            0          3               2015
# 2      City Hotel            1        414               2015
# 3      City Hotel            0         20               2015
# 4      City Hotel            0        117               2015
# ..            ...          ...        ...                ...
# 995  Resort Hotel            0         73               2015
# 996  Resort Hotel            0         14               2015
# 997    City Hotel            1         50               2015
# 998    City Hotel            1         87               2015
# 999  Resort Hotel            0         27               2015
#
#     arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0              October                        41                          7
# 1               August                        35                         23
# ...

# %%
# combine the dataset from different csv file
df_2015 = pd.read_csv('/content/Data_2015.csv')
df_2016 = pd.read_csv('/content/Data_2016.csv')
df_2017 = pd.read_csv('/content/Data_2017.csv')

# concatenate the data frames
merged_df = pd.concat([df_2015, df_2016, df_2017], ignore_index=True)

# print the merged data
print(merged_df)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 0     Resort Hotel            1          4               2015
# 1       City Hotel            0          3               2015
# 2       City Hotel            1        414               2015
# 3       City Hotel            0         20               2015
# 4       City Hotel            0        117               2015
# ...            ...          ...        ...                ...
# 3019    City Hotel            1        164               2017
# 3020  Resort Hotel            0        121               2017
# 3021  Resort Hotel            0          6               2017
# 3022    City Hotel            1         99               2017
# 3023  Resort Hotel            1        167               2017
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               October                        41                          7
# ...

# %%
# to get summary (data type and null values) from dataset using info
merged_df.info()

# covert data type from object to category:
categorical = ['hotel', 'meal', 'market_segment',
               'distribution_channel', 'reserved_room_type',
               'assigned_room_type', 'deposit_type',
               'customer_type', 'reservation_status']
for col in categorical:
  merged_df[col] = merged_df[col].astype('category')

print('\n-------------------------------------------------------------------\n')
# to verify:
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3024 entries, 0 to 3023
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           3024 non-null   object
#  1   is_canceled                     3024 non-null   int64
#  2   lead_time                       3024 non-null   int64
#  3   arrival_date_year               3024 non-null   int64
#  4   arrival_date_month              3024 non-null   object
#  5   arrival_date_week_number        3024 non-null   int64
#  6   arrival_date_day_of_month       3024 non-null   int64
#  7   stays_in_weekend_nights         3024 non-null   int64
#  8   stays_in_week_nights            3024 non-null   int64
#  9   adults                          3024 non-null   int64
#  10  children                        3024 non-null   int64
#  11  babies                          3024 non-null   int64
# ...

# %% [markdown]
# - The merged dataset 2015 to 2017 expected to have 3024 rows. However df.info() reveals that there are missing values in the 'country', 'agent' and 'company' columns which counts of 3015, 2638 and 162 respectively.
#
# - The merged_df.info() also display the types of data for each columns in merged data frame. Based on the inspection, most data types are match the expectation. The 'hotel' variable, intended to be a categorical variable with the values like 'City Hotel' and 'Resort Hotel', is currently represented as an object type. All other columns that represent categorical data are also type object. Object data type are general-purpose data type for strings, but we can change the type of data to category to make the analysis more efficient and clear.

# %% [markdown]
# <font color='red'>**Remember to add comments with hashtags (#) for the code above.**
#
# <font color='red'>**1. What's the purpose of running the above code**
#
# <font color='red'>**2. Based on the output above, do the data types meet your expectations? Please provide an explanation to help guide the readers.**

# %%
# create new column 'total_requests'
# sum of 'required_car_parking_spaces' and 'total_of_special_requests'
merged_df['total_requests'] = merged_df['required_car_parking_spaces'] + merged_df['total_of_special_requests']

# create new column 'total_guests'
# sum of 'adults', 'children' and 'babies'
merged_df['total_guests'] = merged_df['adults'] + merged_df['children'] + merged_df['babies']
print(merged_df)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 0     Resort Hotel            1          4               2015
# 1       City Hotel            0          3               2015
# 2       City Hotel            1        414               2015
# 3       City Hotel            0         20               2015
# 4       City Hotel            0        117               2015
# ...            ...          ...        ...                ...
# 3019    City Hotel            1        164               2017
# 3020  Resort Hotel            0        121               2017
# 3021  Resort Hotel            0          6               2017
# 3022    City Hotel            1         99               2017
# 3023  Resort Hotel            1        167               2017
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               October                        41                          7
# ...

# %%
# drop column that not related to the analysis
# columns to drop
to_drop = ['arrival_date_week_number', 'arrival_date_day_of_month',
           'adults', 'children', 'babies', 'is_repeated_guest',
           'previous_cancellations', 'previous_bookings_not_canceled',
           'agent', 'company', 'days_in_waiting_list',
           'required_car_parking_spaces','total_of_special_requests',
           'reservation_status_date']

# axis = 1 - specifies that dropping the columns, not rows
# inplace = True - the new df doesnt consist the drop columns
merged_df.drop(to_drop, axis = 1, inplace = True)

#  to display the modified data frame
merged_df
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 0     Resort Hotel            1          4               2015
# 1       City Hotel            0          3               2015
# 2       City Hotel            1        414               2015
# 3       City Hotel            0         20               2015
# 4       City Hotel            0        117               2015
# ...            ...          ...        ...                ...
# 3019    City Hotel            1        164               2017
# 3020  Resort Hotel            0        121               2017
# 3021  Resort Hotel            0          6               2017
# 3022    City Hotel            1         99               2017
# 3023  Resort Hotel            1        167               2017
#
#      arrival_date_month  stays_in_weekend_nights  stays_in_week_nights meal  \
# 0               October                        0                     1   BB
# ...

# %% [markdown]
# - The purpose of this code is to remove the columns that are consider irrelevent for this analysis.This reduces dataset to  focus on the important variables, improve the efficiency and make the dataset smaller and more manageable.
#
# - Here, the columns 'required_car_parking_spaces' and 'total_of_special_requests' are removed because a new column, 'total_requests' contains all the necessary information. The 'total_requests' is created by summing the values from  'required_car_parking_spaces' and 'total_of_special_requests'.
#
# - Similarly, 'adults', 'children' and 'babies' column are dropped after creating the 'total_guest' column that represent the sum of these three columns.
#
# - The remaining variables in the to_drop list are removed because the variables are not directly related to the goals of this analysis. This means that these variables do not contribute to addressing the key questions that this analysis seeks to answer.

# %% [markdown]
# <font color='red'>**Comments:**
#
# <font color='red'>**1. Remember to add comments with hashtags (#) for the code above.**
#
# <font color='red'>**- What's the purpose running the above code**

# %%
# get unique value
unique_values = merged_df.nunique()
print(unique_values)
# Out:
# hotel                        2
# is_canceled                  2
# lead_time                  387
# arrival_date_year            3
# arrival_date_month          12
# stays_in_weekend_nights      9
# stays_in_week_nights        17
# meal                         5
# country                     78
# market_segment               7
# distribution_channel         4
# reserved_room_type           8
# assigned_room_type          10
# booking_changes              9
# deposit_type                 3
# customer_type                4
# adr                        988
# reservation_status           3
# total_requests               6
# total_guests                 6
# dtype: int64

# %% [markdown]
# - The .nunique() function is to calculate the number of unique values in each column of the merged_df data frame. Based on the output, we can assess the variety of data within each column. For example, the output shows that the 'hotel' column contains 2 unique values, 78 different countries, 5 unique values for 'meal' column, 8 different room type reserved by guest and 10 room types that the hotel assign to guest. By examining these unique value counts, we can gain crucial insight into the nature of our data before we start our analysis.

# %% [markdown]
# <font color='red'>**Comments:**
#
# <font color='red'>**- What's the purpose running the above code. Give some explanation for the benefits of readers**

# %%
# column name and its unique values
for column in merged_df.columns:
  unique_values = merged_df[column].unique()
  print(column + ":" + str(unique_values))
# Out:
# hotel:['Resort Hotel', 'City Hotel']
# Categories (2, object): ['City Hotel', 'Resort Hotel']
# is_canceled:[1 0]
# lead_time:[  4   3 414  20 117  34  45 276  51 253  22  40 104 295  80   1  17  42
#  323 343 241  90  63  36  37  93 162   0  21  25 178  74   5  29  39  54
#  182  79  12  43 101  82 221   9  76 179 257 135 207   6 290   7  10  32
#   16  28 309 151 344  69  26  35 214  81 335  98 258  83  55  13  44 277
#  219  11 292 140  14 120  38 114 112 297 262  24  46  92  97  30 327 185
#  202   2 193 267  87  31  19 287 205 282 224 260 100  23 273 364  72  18
#   65 138 122 154 336 289 342  48 358  33 148 102 283 105  27  52 265   8
#  326 337  57  61 222 247 294 329 152 332 311 314  53 281  95 227 113  99
#   91  58  15 127  50  84 367 244 111  75 274  41  77 304 161  60  67 159
#  106 272 123 133  59 286 155  66 254 301 149 132 172 532 129  47 110 164
#  136 165 233  89 210 275 231  56  64 147  68 341 141 142  86 168 349 264
# ...

# %% [markdown]
# - The purpose of this code is to provied  detailed view of the unique values within each column. Unlike the previous cell block, which used .nunique() to only shows how many unique values there are. This code uses a loop and the .unique() method to display the full list of unique values present in each columns. By seeing the complete list of unique values, it easier  to find typos, variations in formating or other errors within the values in column.
#
# - For example, in 'meal' column, the output shows 5 types of meals choosen by customer, which 'BB', 'HB', 'FB', 'SC' and 'Undefined. By inspecting the list,  'SC' and 'Undifined' categories are represent the same thing, so they can be grouped in single category, resulting the 'meal' type become only 4 categories. By using this detailed view of data, we can make informed decisions to clean the data for more accurate analysis.

# %% [markdown]
# <font color='red'>**Comments:**
#
# <font color='red'>**- What's the purpose running the above code. Give some explanation for the benefits of readers**

# %%
# 'meal'- ['BB' 'HB' 'FB' 'SC' 'Undefined']
# Undefined and SC represent the same meaning
# combine 'Undefined' and 'SC'
merged_df['meal'] = merged_df['meal'].replace({'Undefined': 'SC'})
print(merged_df['meal'].unique())
# Out:
# ['BB', 'HB', 'FB', 'SC']
# Categories (4, object): ['BB', 'FB', 'HB', 'SC']
# <ipython-input-11-3275c847ecc5>:4: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   merged_df['meal'] = merged_df['meal'].replace({'Undefined': 'SC'})

# %%
# checking for missing value
missing_values = merged_df.isnull().sum()
print(missing_values)
# Out:
# hotel                      0
# is_canceled                0
# lead_time                  0
# arrival_date_year          0
# arrival_date_month         0
# stays_in_weekend_nights    0
# stays_in_week_nights       0
# meal                       0
# country                    9
# market_segment             0
# distribution_channel       0
# reserved_room_type         0
# assigned_room_type         0
# booking_changes            0
# deposit_type               0
# customer_type              0
# adr                        0
# reservation_status         0
# total_requests             0
# total_guests               0
# dtype: int64

# %% [markdown]
# - The .isnull().sum() method is to identify and quantify the missing values for each columns in the dataset. By knowing which columns contains missing data, we can make decisions how to handle these missing values. Based on the output, there are  9 missing values in the 'country' column. This means that for 9 entries in the datasets, there was no recorded country of origin.

# %% [markdown]
# <font color='red'>**Comments:**
#
# <font color='red'>**- What's the purpose running the above code. Give some explanation for the benefits of readers**
#
# <font color='red'>**- Is there any more missing values?**

# %%
# filling the missing data
merged_df['country'] = merged_df['country'].fillna('Unknown')

missing_values = merged_df.isnull().sum()
print(missing_values)
# Out:
# hotel                      0
# is_canceled                0
# lead_time                  0
# arrival_date_year          0
# arrival_date_month         0
# stays_in_weekend_nights    0
# stays_in_week_nights       0
# meal                       0
# country                    0
# market_segment             0
# distribution_channel       0
# reserved_room_type         0
# assigned_room_type         0
# booking_changes            0
# deposit_type               0
# customer_type              0
# adr                        0
# reservation_status         0
# total_requests             0
# total_guests               0
# dtype: int64

# %% [markdown]
# - The code in the previous cell block revealed that there were 9 missing values in the 'country' column. By running these current cell block will fill the missing values. When there are alot of missing data, one strategy is simply to remove entire rows and columns, but it will reduce the amount of data. In the other hand, we can choose to impute, or fill in missing value using other informations.
#
# - Since our dataset is not excessively large, and  the number of missing value is low, it might be undesirable to drop entire rows and columns from the analysis. Filling the missing value is chosen to keep as much data as possible for the analysis so we complete the missing value with 'Unknown' values. So the result show there is no more missing values in 'country' column because we have fill it with the string 'Unknown'.

# %% [markdown]
# <font color='red'>**Comments:**
#
# <font color='red'>**1. If the code in the previous cell block already shows no missing data, why would you still want to fill in the missing data in current cell block?**
#
# <font color='red'>**2. What is your justification for doing so?**

# %% [markdown]
# # **Analysis and Discussion**

# %%
# import the library
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Purpose of Analysis:
# 1.   Customer Preferred:
#     - To analyse the most popular room types book by guests.
#     - To determine the most distribution channel.
#     - To identify the most frequent type of meal booked by customers.
#     - To determine whether guest prefer to stay during weekdays or weekends.

# %%
fig, (ax1, ax2) = plt.subplots(2, 1,  figsize=(15, 15))

# plot country - half of country from dataset
country_counts = merged_df['country'].value_counts().head(40)
colors = sns.color_palette('bright', 40)

# 1st subplot - bar plot
bars_1=ax1.bar(country_counts.index, country_counts, color=colors)
ax1.set_xlabel('Country')
ax1.set_ylabel('Count')
ax1.set_title('Origin of Guest')
ax1.bar_label(bars_1)
ax1.set_xticklabels(country_counts.index, rotation=45, ha='right');


# 2nd subplot - pie chart
# calculate the percentage of 'hotel'
hotel_counts = merged_df['hotel'].value_counts()
hotel_percent = hotel_counts / hotel_counts.sum() * 100

ax2.pie(hotel_percent, labels=hotel_percent.index, autopct='%1.1f%%', startangle=90)
ax2.set_title('Hotel Type')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-15-88aef9b830b4>:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(country_counts.index, rotation=45, ha='right');

# %% [markdown]
# - From the bar plot below 'Origin Of Country' shows that Portugal(PTG) is the dominant origin with the highest number of guest, contributing significantly to the overall guest count. The dominance of PTG followed by Great Britain(GBR), France(FRA), Spain(ESP), DEU(Germany), Italy(ITA) and IRL(Ireland)  as the top 10 most highest number of guest indicate that the hotels represented in data may have strong presence or marketing focus in European market. The frequent representation of European countries maybe that the hotels are located in Europe, making them easily accesssible for travelers from others countries.
#
# - The pie chart 'Hotel Type', City Hotel are the most frequent choose by the guests, for approximately 65.6% and Resort Hotels represent the remaining 34.1% which means maybe greater number of customers are choosing to stay in city-accomodation, indicating that City Hotel may be more common based on this dataset.

# %%
# Group data by year and hotel type
hotel_by_year = merged_df.groupby(['arrival_date_year', 'hotel'])['hotel'].count().unstack()

# stacked bar chart
hotel_by_year.plot(kind='bar', stacked=True)

plt.xlabel('Year')
plt.ylabel('Hotel Count')
plt.title('Hotel Type by Year')
plt.legend(title='Hotel Type')
plt.show()
# Out:
# <ipython-input-16-19fdb09bc06f>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   hotel_by_year = merged_df.groupby(['arrival_date_year', 'hotel'])['hotel'].count().unstack()

# %% [markdown]
# - The stacked bar chart titled 'Hotel Type by Year' provides insights into the distribution of City and Resort hotels over the year from 2015 to 2017. From all three years, the customers preferred City Hotel compared to Resort Hotel. The plot indicates a trend of increasing City Hotel accomodations from 2015 to 2017. Conversely, the propotion of Resort Hotel accomodations decrease over the time. This suggests a growing focus on City Hotel development compared to Resort Hotel. This trend could be  attributed to several factors. For example, major cities typically has become the main attraction to the tourist such as museums, entertainment option, and near to transportation hubs. These factor make City Hotel become the popular choice for travelers seeking accessibility and urban experiences.
#
# - According to reports from World Tourism Organization (UNWTO), urban tourism is experiencing significant growth worldwide. The UNWTO expect that the world's urban population will increase by 61% by 2030, the volume people living in cities will rise to 5 billion people. This substantial growth in urban population will have a considerable impact on urban tourism, driving demand for City Hotel accomodations.
#
#  References:
#  1. https://www.unwto.org/tourism-statistics
#  2. World Tourism Organization (UNWTO). (2012). Global Report on City Tourism AM Reports: Volume six. https://webunwto.s3-eu-west-1.amazonaws.com/imported_images/46742/am6_city_platma.pdf
#
# <font color='red'>**Comments:**
#
# <font color='red'>**1. The bar plot shows a trend where City Hotel accommodation increases from 2015 to 2017, while the proportion of Resort Hotel accommodations decreases in the opposite direction.**
#
# <font color='red'>**2. Would you like to comment on this trend?**
#
# <font color='red'>**3. Did you come across any published reports that mention similar observations?**

# %%
# change to CategoricalDtype - specific order (Jan, Feb, ..., Dec)
month_order= ['January', 'February', 'March', 'April', 'May', 'June',
         'July', 'August', 'September', 'October', 'November', 'December']
month_dtype = pd.CategoricalDtype(categories=month_order, ordered=True)
merged_df['arrival_date_month'] = merged_df['arrival_date_month'].astype(month_dtype)

# create new column 'booking_count' - how many booking for evey month
bookings_df = merged_df.groupby(['arrival_date_month', 'hotel'], observed=True)['hotel'].count().reset_index(name='bookings_count')

# line plot for the City Hotel
plt.figure(figsize=(12, 6))
sns.lineplot(x='arrival_date_month', y='bookings_count',
             data=bookings_df[bookings_df['hotel'] == 'City Hotel'],
             marker='o', label='City Hotel')

# line plot for the Resort Hotel
sns.lineplot(x='arrival_date_month', y='bookings_count',
             data=bookings_df[bookings_df['hotel'] == 'Resort Hotel'],
             marker='s', label='Resort Hotel')

plt.title('Booking Trends by Month, Booking Type, and Hotel')
plt.xlabel('Month')
plt.ylabel('Number of Bookings')
plt.legend(title='Hotel and Booking Type', loc='lower right')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# - The graph illustrate the number of bookings for City Hotels across different months of the year. Both hotels types experience varying levels of demand through the year, with August being a peak season for both. Usually July and August fall within summer months, where this months, school having summer break, so many families and individuals will use this time to go for vacation. Futhermore, favorable summer weather conditions often encorage many outdoor activities, further driving demand for both hotels.
#
# - The lowest number of booking for both hotels are in January, this maybe because the peak holiday season just have passed like Christmas and New Year's and people might be recovering travel expenses or back to daily routines which go to school, and work. Beside that, after the excitment and often hectic nature of the holiday season, many people may simply desire a period of rest and relaxation at home, which this situation leading to decrease in travel demand.

# %%
# change to CategoricalDtype - specific order (Jan, Feb, ..., Dec)
month_dtype = pd.CategoricalDtype(categories=month_order, ordered=True)
merged_df['arrival_date_month'] = merged_df['arrival_date_month'].astype(month_dtype)

# create new column adr - which is  average adr
adr_df = merged_df.groupby(['arrival_date_month', 'hotel'], observed=True)['adr'].mean().reset_index()

# line plot for the City Hotel
plt.figure(figsize=(12, 6))
sns.lineplot(x='arrival_date_month', y='adr',
             data=adr_df[adr_df['hotel'] == 'City Hotel'],
             marker='o', label='City Hotel')

# line plot for the Resort Hotel
sns.lineplot(x='arrival_date_month', y='adr',
             data=adr_df[adr_df['hotel'] == 'Resort Hotel'],
             marker='s', label='Resort Hotel')

plt.title('Average Daily Rate (ADR) by Month, and Hotel')
plt.xlabel('Month')
plt.ylabel('ADR')
plt.legend(title='Hotel and Booking Type', loc='upper left')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# - This graph ilustrate the  ADR for both City Hotels and Resort Hotels across different months of the year. City Hotels shows a generally upward trend from January to May, followed by a slighly decline towards the end of the year. In contrast, Resort Hotels shows a significant peak in ADR during August, followed by a sharp decline in the following months.
#
# - Although, for City Hotel has highest number of booking during summer month of July and August, the for ADR show a decline during that months. This can be attribute to several potential factors which during this month there is likely a surge in demand for hotel. This increased competition among hotel that can lead to hotel to offer discounts or promotions to attract guests. Beside that, guests often book hotels in advance, especially during peak season, and the hotel might offer earlier booking discount to incentive reservation which lead to a lower ADR during the actual stay months.
#
# - The clear peak in August for Resort Hotel strongly suggests a period of exceptionallly high demand. This peak is significantly higher than any other month, indicating a unique factor driving up the ADR in August. The resort may host or be located near special events or festivals that occur in August, driving up demand allowing the resort charge higher prices. If the resort  has limited availability during August, they can command higher prices.
#
# - For example, Drayton Manor Resort is a popular  family-oriented attraction located in Staffordshire, England, experiences a significant  surge  in visitors during the summer months, particularly August. This is drivn by school holidays, favorable weather and a range of events held within the resort including themed attractions and special shows. Consequently, Drayton Manor can charge higher prices during this period due to increased demand and limited availability. The higher price  and increased demand during the summer can justify the higher ADR.
#
# - Reference: https://www.draytonmanor.co.uk/theme-park/events
#
# <font color='red'>**Comment:**
#
# <font color='red'>**1. What is your interpretation of the clear peak in August for Resort Hotel?**
#
# <font color='red'>**2. What could explain the significant increase in ADR during that period?**

# %%
# count the value for 'reserved_room_type'
reserve_room_counts = merged_df['reserved_room_type'].value_counts()

# color
colors = sns.color_palette('bright', 10)

# bar plot
bars_1 = plt.bar(reserve_room_counts.index, reserve_room_counts,color=colors )
plt.xlabel('Room')
plt.ylabel('Count')
plt.title('Reserved Room by Customers')
plt.bar_label(bars_1)
plt.show()

# %% [markdown]
# - From the bar chart 'Reserved Room by Customer' above, Room A become the most frequently reserved room than any other type which 2250 reservations. Room D become the second highest with 476 reservation by guests, and the lowest chosen room is Room H. The specific details of room types A to H were not provided with this dataset, we cannot definitely determine the room types but we can still observe the relative popularity of each based on frequency of reservation.
#
# - Room A demonstrates significantly higher reservation frequency than all other room. It is commonly observed in the hospitality industry that the standard room which are the most basic and typically more affordable room type, tend to have higher occupancy rates. It is possible that room A represents such a standard room. The standard room  make it attractive choice for budget-conscious traveler, including solo or family travelers. In contrast, luxury suite, such as those that include larger living area, a separate dining room and kitchenette are often less frequently booked than standard rooms, due to higher cost. This could be a contributing factor to the lower reservation numbers seen in room H.
#
# <font color='red'>**Comments:**
#
# <font color='red'>**1. Could you clarify the exact room types labeled from A to H?**
#
# <font color='red'>**2. The term "might be" could raise concerns with stakeholders, as it suggests uncertainty. This could imply that the exact information wasn’t thoroughly researched, don’t you think?**
#
# <font color='red'>**3. If the information is truly unavailable, you should clearly state the issue regarding the lack of available data.**

# %%
# reserved_room_type
plt.figure(figsize=(12, 6))
sns.countplot(x='reserved_room_type', hue='hotel', data=merged_df)
plt.title('Reserved Room Type by Hotel')
plt.xlabel('Reserved Room Type')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Hotel Type')
plt.show()

# %% [markdown]
# - The bar chart 'Reserved RoomType by Hotel' shows that guests at City Hotel reserve Room Types A, B, D, E, F and G while for guests at Resort Hotel reserve Room Types A, C, D, E, F, G, and H. When we compared both hotels, it obviously shows that for both type of hotels, customers preferred Room A, and Room D also the second choice but for the Room E, Resort Hotel become the higher choice of reservation.
#
# - Resort Hotels typically attract families and groups.The significantly higher frequently reservation of Room Type E at Resort Hotel suggests it may carter to  family room that designed to accommodate families that typically have multiple beds, connecting rooms, or others amenities that would be attractive to resort guests.
#
# <font color='red'>**Comments:**
#
# <font color='red'>**1. Why did you suddenly change the color scheme for City and Resort Hotels? In the previous cell blocks, blue was used for City Hotel and orange for Resort Hotel.**
#
# <font color='red'>**2. Please use a consistent color scheme to avoid confusion and ensure clarity.**
#
# <font color='red'>**3. Please update the color scheme for the whole colab notebook acordingly**

# %%
# distribution_channel
sns.countplot(x='distribution_channel', hue='hotel', data=merged_df)
plt.title('Distribution Channel by Hotel Type')
plt.xlabel('Distribution Channel')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Hotel Type')
plt.show()

# %% [markdown]
# - Both hotel groups commonly used Travel Agents (TA) and Tour Operators (TO) as the distribution channels. However, the use of Global Distribution System (GDS) differs, which only used by City Hotel. GDS is the vast computer network that allowed customers to search and book travel products such as hotels, flight and other from various suppliers in single system.
#
# - The high use of TA and TO as distribution channels could be due to some factors like packaged that offered by them, the expertise of travel agents in recommending best hotels that fulfill customers need and their ability to facilitate and assist group booking. The direct booking channel is the second distribution channel that help the guest booking their stays maybe because of spontaneous travel decisions and the desire for greater flexibility and control over the booking process.

# %%
# frequent meal booked by guest
plt.figure(figsize=(12, 6))
sns.countplot(x='meal', hue='hotel', data=merged_df)
plt.title(' Meal by Hotel')
plt.xlabel('Meal Type')
plt.ylabel('Count')
plt.legend(title='Hotel')
plt.show()

# %% [markdown]
# - For both hotels, customers preferred to book and have bed and breakfast(BB) type, indicating that  they want to have only breakfast included with their room bookings, while Half Board (HB) is the second most popular meal type option which guest also want to have one other meal.
#
# - This suggests that, customers generally prefer to have at least one meal, typically breakfast, included with their room booking. The small demand for Full Board (FB), encompassing breakfast, lunch and dinner, indicates that guests may prioritize experiencing local cuisine and exploring dining options beyond the hotel, such as trying street food. Additionally, some customers choose no meal package(SC), possibly indicating a preference for budget-conscious travel.

# %%
# plot for'stays_in_weekend_nights' and 'stays_in_week_nights' by 'hotel'
# group data by hotel type
# calculate average for night stay
hotel_stays = merged_df.groupby('hotel')[['stays_in_weekend_nights', 'stays_in_week_nights']].mean().reset_index()

# from 'hotel_stay', there are three column - 'hotel', 'stays_in_weekend_nights', 'stays_in_week_nights'
# add another column (average_night)
# 'stays_in_weekend_nights', 'stays_in_week_nights' become one column = 'stay_type'
hotel_melt = hotel_stays.melt(id_vars=['hotel'], var_name='stay_type', value_name='average_nights')

# create the grouped bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='hotel', y='average_nights', hue='stay_type', data=hotel_melt, palette='muted')
plt.title('Average Stays in Weekend and Week Nights by Hotel Type')
plt.xlabel('Hotel Type')
plt.ylabel('Average Number of Nights')
plt.legend(title='Stay Type')
plt.show()
# Out:
# <ipython-input-23-a0299a1becef>:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   hotel_stays = merged_df.groupby('hotel')[['stays_in_weekend_nights', 'stays_in_week_nights']].mean().reset_index()

# %% [markdown]
#  - Although many customers prefers to choose City Hotel, but in terms of time stay at the hotel, guests tend to spend longer durations at Resort Hotels. This is likely due to the fact that business travelers who often have shorter stays for meetings or conferences are more likely to stay at City Hotel. In the other hand, for Resort Hotels attract more leisure travelers who are looking for longer vacations and extended stays. Usually Resort Hotels often located near to beach and outside urban area, so there are many activities that guests can do such as beach volleyball, swimming, sunbathing, spas treatments and others. These will encourage guests to extend their stays and enjoy their leisure time.
#
# - Furthermore, guests also tend to stay more on weekdays while the shorter average stay for weekend maybe because many guests use weekend for short gateways or just to take a time to relax their mind before start a busy workweeks. Another factor that may contribute to this result is the price per room difference between weekdays and weekends. Weekday rates are often lower compared to weekend rates, which can be significantly higher, potentially double from normal price.

# %% [markdown]
# ### Purpose of Analysis:
# 2.   ADR:
#     - To understand how well the hotel is meeting customer expectations in terms of room type.

# %%
# box plot
# to look at customer preference - the room the guest reserve
sns.boxplot(x='reserved_room_type', y='adr', data=merged_df,
            hue='reserved_room_type' , palette='bright',
           order=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'])
plt.title(' Reserved Room Type vs ADR')
plt.xlabel('Reserved Room Type')
plt.ylabel('ADR')
plt.show()

# %% [markdown]
# - The box plot shows variations in the Average Daily Rate (ADR) across different room types. Secifically, Room type A and B have lower ADR values compared to theother room types. For Room A shows the narrowest range  of ADR and  the lowest median ADR. Although Room A is the most popular room reserved by guests, but the ADR is low. One possible reasons is that the hotels utilized the Room A as a 'loss leader' to attract guests. This strategy invoves offering a popular, lower-priced option to entice booking. Once the guests arrived at hotel, the hotel can upsell them on more expensive services or amenities such as offering guests the chance to upgrade to a larger room, discount on spas packages,and others.
#
# Reference: https://www.siteminder.com/r/hotel-upselling/#:~:text=Hotel%20upselling%20is%20the%20practice,stay%2C%20beyond%20their%20initial%20booking.
#
# - Room H have higher median ADR and wider ranges, indicating that these are likely more upscale or premium room types with varying levels of luxury and amenities.
#
# - There are several outliers present in the box plot, particularly for some of the higher-priced room types. These outliers could represent exceptionally high-priced rooms or special offers.

# %% [markdown]
# ### Purpose of Analysis:
# 3.   Cancellation:
#     - Does the room assigned to guests, number of days before actual arrival of guests, market segments and type of deposits give an impact to the booking cancellation?

# %%
# 'assigned_room_type' vs '_is_canceled'
plt.figure(figsize=(12, 6))
sns.countplot(x='assigned_room_type', hue='is_canceled', data=merged_df,
             palette={0: "orange", 1: "green"})
plt.title('Assigned Room Type vs. Cancellation')
plt.xlabel('Assigned Room Type')
plt.ylabel('Count')
plt.legend(title='Cancellation', labels= ['No', 'Yes'])
plt.show()

# %% [markdown]
# - As we look before, the most popular room choose by guests during resrvation is Room A, but as the plot bar 'Assigned Room Type vs. Cancellation' above show that Room A also has a higher for non-cancellation.
#
# - There maybe some factors that contribute to this observations. Firstly, Room A, with attractive features such as larger size, better view , and potentially affordable in price, may lead to higher guest satisfaction and contribute less likely to cancel. In addition, other than Room A, we can see that the number of non-cancelled booking is generally lower compared to the number of cancellation. This shows that guests satisfied with the assigned room. If the assigned room does not meet their expectation or if unexpected additional cost arise, guests may be more likely to cancel the reservations.

# %%
# lead_time' vs 'is_canceled'
plt.figure(figsize=(10, 6))
sns.histplot(data=merged_df, x='lead_time', hue='is_canceled',
             palette={0: "orange", 1: "green"}, multiple='stack')
plt.title('Distribution of Lead Time by Cancellation Status')
plt.xlabel('Lead Time (days)')
plt.ylabel('Count')
plt.legend(title='Cancellation', labels= ['Yes', 'No'])
plt.show()

# %% [markdown]
# - The bar plot indicates that as the the numbers of days before actual date decrease, the number for guest cancellations generally decrease. However, there is still a chance that the guests will cancel the booking even when they are close to the actual date. This could be due to unforeseen circumstances, last minute changes in plans or other factors.
#
# - The higher frequency of shorter lead times can be influence by few factors. Usually, guests tend to book the room closer to their arrrival date. Other than that, maybe because of spontaneous travel decisions made by customers. Customers may book last-minute trips due to sudden travel plan.

# %%
# count the value for 'market_segment'
ms_counts = merged_df['market_segment'].value_counts()

# color
colors = sns.color_palette('bright', 10)

# bar plot
bars_2 = plt.bar(ms_counts.index, ms_counts,
        color=colors, width=0.5)
plt.xlabel('Market Segment')
plt.ylabel('Count')
plt.title('Type of Market Segment')
plt.xticks(rotation=45, ha='right')
plt.bar_label(bars_2)
plt.show()

# %% [markdown]
# - In the context of hotel industry, 'market segment' refers to a group of customers withs similar characteristics.
#
# - The largest segment is Online TA (Travel Agencies), indicating that bookings are made through online travel agencies like Booking.com, Opodo and Expedia and the smallest  segment is aviation which represent the bookings was made by airline crew members.
# Additionally, there is a segment call Offline TA/TO which represent booking made through traditional travel agency or tour operator. For group segment, represent booking made by groups, such as families or friends. Other than that, there also have direct, corporate and complementary segment, which direct includes booking was made directly with hotel, which through call or hotel's website. Corporate refers to booking made by companies for their employees or business travel and lastly complementary segment might make booking through partnerships with other busuiness such as airlines or tour operators.
#
# - Reference: https://www.canarytechnologies.com/post/hotel-market-segmentation#5-common-hotel-market-segments-worth-getting-to-know

# %%
# 'market_segment' vs 'is_cancel' - diff type 'hotel'
# create the catplot
cp = sns.catplot(x='market_segment', hue='is_canceled', col='hotel',
            data=merged_df, kind='count', palette={0: "orange", 1: "green"},
            height=5, aspect=1.5, legend=False)

# set titles and labels
cp.fig.suptitle('Market Segment vs Cancellation Status')
cp.set_xlabels('Market Segment')
cp.set_ylabels('Count')
cp.add_legend(title='Cancellation', labels= ['No', 'Yes'])
cp.set_xticklabels(rotation=45, ha='right')

plt.show()

# %% [markdown]
# - The chart show the relationship between market segment and cancellation status, whether the reservation was canceled or not for both types of hotels. Both hotels shows that 'Online TA' has highest number for both canceled and non canceled reservations. According to 'Group' segment, in City Hotel, number of cancellation is higher, while in Resort Hotel, number of cancellation is fewer. For both hotel types, 'Complementary' and 'Aviation' have very low number of cancellations as well as the number of booking.
#
# - Online TA such as Booking.com have a wide reach and are easily accessible to people who want to travel. This high visibility leads to significant volume of bookings through this channel and also will giving travelers to easy of booking hotel and also easy in canceling. This is one of the reason that might lead to a higher number pf cancellations compared to traditional booking methods.

# %%
# 'deposit_type' vs 'is_cancel' - diff type 'hotel'
# create the catplot
cp = sns.catplot(x='deposit_type', hue='is_canceled', col='hotel',
            data=merged_df, kind='count', palette={0: "orange", 1: "green"},
            height=5, aspect=1.5, legend=False)

# set titles and labels
cp.fig.suptitle('Type of Deposit vs Cancellation Status')
cp.set_xlabels('Type of Deposit')
cp.set_ylabels('Count')
cp.add_legend(title='Cancellation', labels= ['Yes', 'No'])
cp.set_xticklabels(rotation=45, ha='right')

plt.show()

# %% [markdown]
# - From the dataset, there are three types of deposits which are no deposit, no  refund, and refundable. For both hotels have the same pattern where the reservation with no deposit have the highest number of cancellation.
#
# - A 'no deposit' policy allows guests to book reservations without paying any money upfront. Guests might easily reserve multiples room without they need to worry about any financial penalty, since there is no financial commitment. This will increase the probability of overbooking for the hotel and lead to higher potential of cancellation. Besides that, guests who choose the no deposit options might be easily switch to another hotel if they find a better deal or encounter unexpected expenses.
#
# - However, the non refundable option has higher number of non-canceled reservation. This type requires to pay a deposit up ahead that is no money will be paid back to guests if they cancel the reservation within a certain time frame. The lower number of cancellation may be because of guests tend to carefully think before decide decision regarding their travel plan. Financial penalty is one of the main reasons that guests need to take consideration about their travel plan. Guests who have already paid for the room resrvation will lose their money if cancellation is made.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# - In conclusion, by analysing customer preference, Average Daily Rate (ADR) and relationship of various factors with cancellation, both hotels can gain some valuable insights to optimize operation, increase profitability and also help creat a positive business impact.
#
# - Analysing the reserved room types by guests can reveal the most frequently booked room type. Both hotels should prioritize the availability and potentially adjust pricing strategies for high demand rooms. Next, analysing distribution channels, type of meal, and weekend or weekdays stay can help business understanding customers preference that can guide business to strucure successful marketing campaigns and provide services that align with guests preferences. In addition, with the understanding values of ADR with different assigned room types can help business management  make informed decisions about pricing strategies and room inventory management to maximize revenue.
#
# - Lastly, understanding the factors such as room assigned to guests, number of days before actual arrival of guests, market segments and type of deposits taht maybe contribute to cancellations can help implement strategies to reduce cancellations and improve guest satisfaction, such as offer flexible cancellation options to accommodate guest needs and reduce the risk of last-minute cancellations, mplement deposit policies that balance guest flexibility with revenue protection and others.
#
# - By continuously monitoring these key areas and adapting strategies based on the insights gained, hotels can enhance the guest experience, optimize revenue, and achieve sustainable growth. Other than that, further analysis is required to help the business maintain and improve their revenue in the futures.
